# %% [markdown]
# # User 003: Heatmap
# - Cluster by Cell_Size
# - Visualize Points of Interest
# - Fits within grid and data per cell

# %%
# Personal lib
import heatmap as hp

# %%
# Static
cell_size = 0.025 # square miles
LengthPixel = 15
WidthPixel = 23

# %%
hp.allUserMonths('003', cell_size, WidthPixel, LengthPixel)
# Out:
# Records: 13601
# Latidude 	 Min: 39.906149 	 Max: 40.013659
# Longitude 	 Min: 116.182847 	 Max: 116.368577
# Records: 49830
# Latidude 	 Min: 39.829767 	 Max: 40.065465
# Longitude 	 Min: 116.267940 	 Max: 116.483709
# Records: 82860
# Latidude 	 Min: 39.713132 	 Max: 40.082069
# Longitude 	 Min: 116.265261 	 Max: 116.614078
# Records: 67469
# Latidude 	 Min: 31.968197 	 Max: 40.223747
# Longitude 	 Min: 116.216938 	 Max: 121.275151
# Records: 58839
# Latidude 	 Min: 31.999307 	 Max: 40.200719
# Longitude 	 Min: 116.222514 	 Max: 121.274149
# Records: 54477
# Latidude 	 Min: 31.249504 	 Max: 40.017779
# Longitude 	 Min: 116.201550 	 Max: 121.547725
# Records: 59436
# Latidude 	 Min: 39.762202 	 Max: 40.080675
# Longitude 	 Min: 116.201597 	 Max: 116.802267
# Records: 39057
# Latidude 	 Min: 31.167749 	 Max: 40.081138
# Longitude 	 Min: 116.290036 	 Max: 121.479839
# Records: 49084
# Latidude 	 Min: 31.095299 	 Max: 40.210960
# Longitude 	 Min: 116.071547 	 Max: 121.555706
# ...
