# %% [markdown]
# # User 004: Heatmap
# - Cluster by Cell_Size
# - Visualize Points of Interest
# - Fits within grid and data per cell

# %%
# Personal lib
import heatmap as hp

# %%
# Static
cell_size = 0.1 # square miles
LengthPixel = 15
WidthPixel = 23

# %%
hp.allUserMonths('004', cell_size, WidthPixel, LengthPixel)
# Out:
# Records: 8765
# Latidude 	 Min: 39.956417 	 Max: 40.012031
# Longitude 	 Min: 116.308741 	 Max: 116.416777
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 35044
# Latidude 	 Min: 39.898895 	 Max: 40.070893
# Longitude 	 Min: 116.292970 	 Max: 116.483703
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 46147
# Latidude 	 Min: 39.818414 	 Max: 40.080241
# Longitude 	 Min: 116.265181 	 Max: 116.614045
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 45470
# Latidude 	 Min: 38.871165 	 Max: 41.367085
# Longitude 	 Min: 116.216941 	 Max: 122.651456
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 59294
# Latidude 	 Min: 38.871072 	 Max: 40.089947
# Longitude 	 Min: 116.201588 	 Max: 122.001293
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 44300
# Latidude 	 Min: 39.762174 	 Max: 40.053860
# Longitude 	 Min: 116.201602 	 Max: 116.418420
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 62602
# Latidude 	 Min: 39.731670 	 Max: 40.052035
# Longitude 	 Min: 116.201535 	 Max: 116.801939
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 44467
# Latidude 	 Min: 31.167747 	 Max: 40.087663
# Longitude 	 Min: 116.220481 	 Max: 121.483821
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 41535
# Latidude 	 Min: 39.939392 	 Max: 40.210947
# Longitude 	 Min: 116.071590 	 Max: 116.496188
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 51773
# Latidude 	 Min: 39.894713 	 Max: 40.053952
# Longitude 	 Min: 116.293589 	 Max: 116.613960
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
