# %% [markdown]
# # Heatmap Process
# - Cluster by Cell_Size
# - Group many similar locations together
# - Fits in set grid

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp
import seaborn as sns

# Personal lib
import importCSV as csv
import heatmap as hp

# %%
# Static
cell_size = 0.5 # square miles
LengthPixel = 15
WidthPixel = 23

one = 'split_by_month_output/000/2008_10.csv'
two = 'split_by_month_output/000/2008_11.csv'
three = 'split_by_month_output/000/2008_12.csv'
four = 'split_by_month_output/000/2009_03.csv'
five = 'split_by_month_output/000/2009_04.csv'
six = 'split_by_month_output/000/2009_05.csv'
seven = 'split_by_month_output/000/2009_07.csv'

hp.monthHeatMap(one, cell_size, WidthPixel, LengthPixel)
hp.monthHeatMap(two, cell_size, WidthPixel, LengthPixel)
hp.monthHeatMap(three, cell_size, WidthPixel, LengthPixel)
hp.monthHeatMap(four, cell_size, WidthPixel, LengthPixel)
hp.monthHeatMap(five, cell_size, WidthPixel, LengthPixel)
hp.monthHeatMap(six, cell_size, WidthPixel, LengthPixel)
hp.monthHeatMap(seven, cell_size, WidthPixel, LengthPixel)
# Out:
# Number of records for user: 3627
# Bounding Box within range:
# Latidude 	 Min: 39.887104 	 Max: 40.012658
# Longitude 	 Min: 116.285446 	 Max: 116.394204
# Total Width 7.504302000000607 miles
# Total Length 7.533240000000063 miles
# Number of records for user: 7745
# Bounding Box within range:
# Latidude 	 Min: 39.950649 	 Max: 40.021469
# Longitude 	 Min: 116.29435900000001 	 Max: 116.333359
# Total Width 2.6909999999991214 miles
# Total Length 4.249200000000286 miles
# Number of records for user: 1570
# Bounding Box within range:
# Latidude 	 Min: 39.994071000000005 	 Max: 40.012646999999994
# Longitude 	 Min: 116.31553999999998 	 Max: 116.32786399999999
# Total Width 0.8503560000004597 miles
# Total Length 1.1145599999993294 miles
# Number of records for user: 2778
# Bounding Box within range:
# Latidude 	 Min: 39.990463 	 Max: 40.014803
# Longitude 	 Min: 116.314421 	 Max: 116.32881599999999
# Total Width 0.9932549999995359 miles
# Total Length 1.460400000000135 miles
# ...
