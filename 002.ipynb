# %% [markdown]
# # User 002: Heatmap
# - Cluster by Cell_Size
# - Visualize Points of Interest
# - Fits within grid and data per cell

# %%
# Personal lib
import heatmap as hp

# %%
# Static
cell_size = 0.1 # square miles
LengthPixel = 15
WidthPixel = 23

# %%
hp.allUserMonths('002', cell_size, WidthPixel, LengthPixel)
# Out:
# Records: 28852
# Latidude 	 Min: 39.893561 	 Max: 39.984360
# Longitude 	 Min: 116.171926 	 Max: 116.391503
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 63878
# Latidude 	 Min: 39.879156 	 Max: 40.004515
# Longitude 	 Min: 116.101195 	 Max: 116.390690
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 34528
# Latidude 	 Min: 39.895697 	 Max: 39.998546
# Longitude 	 Min: 116.206273 	 Max: 116.467675
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 38343
# Latidude 	 Min: 37.230660 	 Max: 39.984890
# Longitude 	 Min: 110.719933 	 Max: 116.388958
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 53396
# Latidude 	 Min: 39.781571 	 Max: 40.052399
# Longitude 	 Min: 116.206200 	 Max: 116.656566
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 29220
# Latidude 	 Min: 39.893351 	 Max: 40.052236
# Longitude 	 Min: 116.192834 	 Max: 116.389611
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
