# %% [markdown]
# # User 001: Heatmap
# - Cluster by Cell_Size
# - Visualize Points of Interest
# - Fits within grid and data per cell

# %%
# Personal lib
import heatmap as hp

# %%
# Static
cell_size = 0.025 # square miles
LengthPixel = 15
WidthPixel = 23

# %%
hp.allUserMonths('001', cell_size, WidthPixel, LengthPixel)
# Out:
# Records: 23937
# Latidude 	 Min: 39.967374 	 Max: 40.076106
# Longitude 	 Min: 116.145054 	 Max: 116.387052
# Records: 49680
# Latidude 	 Min: 39.900944 	 Max: 40.076116
# Longitude 	 Min: 116.292749 	 Max: 116.422699
# Records: 34990
# Latidude 	 Min: 39.902628 	 Max: 40.016820
# Longitude 	 Min: 116.305435 	 Max: 116.443578
