# %% [markdown]
# # User 000: Heatmap
# - Cluster by Cell_Size
# - Visualize Points of Interest
# - Fits within grid and data per cell

# %%
# Personal lib
import heatmap as hp

# %%
# Static
cell_size = 0.1 # square miles
LengthPixel = 15
WidthPixel = 23

# %%
hp.allUserMonths('000', cell_size, WidthPixel, LengthPixel)
# Out:
# Records: 3627
# Latidude 	 Min: 39.887104 	 Max: 40.012658
# Longitude 	 Min: 116.285446 	 Max: 116.394204
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 7745
# Latidude 	 Min: 39.950649 	 Max: 40.021469
# Longitude 	 Min: 116.294359 	 Max: 116.333359
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 1570
# Latidude 	 Min: 39.994071 	 Max: 40.012647
# Longitude 	 Min: 116.315540 	 Max: 116.327864
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 2778
# Latidude 	 Min: 39.990463 	 Max: 40.014803
# Longitude 	 Min: 116.314421 	 Max: 116.328816
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 59436
# Latidude 	 Min: 39.762202 	 Max: 40.080675
# Longitude 	 Min: 116.201597 	 Max: 116.802267
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 39057
# Latidude 	 Min: 31.167749 	 Max: 40.081138
# Longitude 	 Min: 116.290036 	 Max: 121.479839
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 49084
# Latidude 	 Min: 31.095299 	 Max: 40.210960
# Longitude 	 Min: 116.071547 	 Max: 121.555706
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
# Records: 10573
# Latidude 	 Min: 39.950378 	 Max: 40.081442
# Longitude 	 Min: 116.232679 	 Max: 116.368441
# Cell_Size -- Lat:0.0014492753623188406 	 in Miles: 0.1
# Cell_Size -- Lon:0.0016666666666666668 	 in Miles: 0.1
