# %% [markdown]
# # User 005: Heatmap
# - Cluster by Cell_Size
# - Visualize Points of Interest
# - Fits within grid and data per cell

# %%
# Personal lib
import heatmap as hp

# %%
# Static
cell_size = 0.025 # square miles
LengthPixel = 15
WidthPixel = 23

# %%
hp.allUserMonths('005', cell_size, WidthPixel, LengthPixel)
# Out:
# Records: 20113
# Latidude 	 Min: 39.906169 	 Max: 40.013128
# Longitude 	 Min: 116.182813 	 Max: 116.361914
# Records: 50145
# Latidude 	 Min: 22.147577 	 Max: 40.016641
# Longitude 	 Min: 113.548843 	 Max: 116.364809
# Records: 2094
# Latidude 	 Min: 39.833705 	 Max: 40.011133
# Longitude 	 Min: 116.267787 	 Max: 116.336559
# Records: 31086
# Latidude 	 Min: 39.902977 	 Max: 41.119180
# Longitude 	 Min: 116.312037 	 Max: 121.155509
# Records: 4359
# Latidude 	 Min: 39.989882 	 Max: 41.132062
# Longitude 	 Min: 116.312184 	 Max: 121.156224
# Records: 1249
# Latidude 	 Min: 39.977663 	 Max: 40.011840
# Longitude 	 Min: 116.313697 	 Max: 116.335148
